# %% [markdown]
# # EDA

# %% [markdown]
# ## Imports

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %% [markdown]
# ### Fake image from train set

# %%
image_path = '/home/thomas/code/dfake/dfake-models/data/real-vs-fake/train/fake/00A0WLZE5X.jpg'

# %%
img = np.array(Image.open(image_path))
plt.imshow(img)

# %%
img.shape
# Out:
# (256, 256, 3)

# %%
img
# Out:
# array([[[178, 165, 156],
#         [182, 169, 160],
#         [184, 171, 162],
#         ...,
#         [177, 163, 154],
#         [177, 163, 152],
#         [177, 163, 152]],
#
#        [[182, 169, 160],
#         [184, 171, 162],
#         [184, 171, 162],
#         ...,
#         [180, 166, 157],
#         [179, 165, 154],
#         [177, 163, 152]],
#
#        [[185, 172, 163],
#         [185, 172, 163],
#         [184, 171, 162],
#         ...,
#         [183, 169, 160],
#         [181, 167, 156],
#         [178, 164, 153]],
#
#        ...,
#
#        [[ 43,  41,  54],
#         [ 44,  44,  56],
#         [ 47,  45,  58],
#         ...,
#         [173, 159, 156],
#         [169, 156, 150],
#         [171, 158, 152]],
#
#        [[ 43,  42,  58],
#         [ 45,  47,  62],
#         [ 45,  44,  60],
#         ...,
#         [172, 161, 159],
#         [165, 154, 150],
#         [169, 158, 154]],
#
#        [[ 46,  47,  65],
#         [ 49,  50,  68],
#         [ 45,  47,  62],
# ...

# %% [markdown]
# ### Real image from train set

# %%
image_path = '/home/thomas/code/dfake/dfake-models/data/real-vs-fake/train/real/00000.jpg'
img = np.array(Image.open(image_path))
plt.imshow(img)

# %% [markdown]
# ### Fake mage from valid set

# %%
image_path = '/home/thomas/code/dfake/dfake-models/data/real-vs-fake/valid/fake/00BYVMEI3I.jpg'
img = np.array(Image.open(image_path))
plt.imshow(img)

# %%
img.shape
# Out:
# (256, 256, 3)

# %%
img
# Out:
# array([[[170,  51,  31],
#         [164,  45,  23],
#         [175,  54,  33],
#         ...,
#         [165,  53,  29],
#         [167,  55,  35],
#         [162,  51,  31]],
#
#        [[171,  52,  32],
#         [160,  41,  19],
#         [173,  53,  29],
#         ...,
#         [163,  49,  25],
#         [166,  54,  32],
#         [163,  53,  30]],
#
#        [[168,  49,  27],
#         [165,  46,  22],
#         [172,  52,  28],
#         ...,
#         [163,  49,  25],
#         [166,  52,  28],
#         [162,  50,  26]],
#
#        ...,
#
#        [[158,  39,  17],
#         [160,  41,  19],
#         [157,  38,  18],
#         ...,
#         [ 76,  45,  27],
#         [107,  76,  58],
#         [130,  99,  81]],
#
#        [[160,  41,  19],
#         [162,  43,  21],
#         [160,  41,  21],
#         ...,
#         [ 64,  35,  19],
#         [130, 101,  83],
#         [139, 110,  92]],
#
#        [[169,  50,  28],
#         [160,  41,  19],
#         [158,  39,  19],
# ...

# %% [markdown]
# ### Real image from valid set

# %%
image_path = '/home/thomas/code/dfake/dfake-models/data/real-vs-fake/valid/real/00005.jpg'
img = np.array(Image.open(image_path))
plt.imshow(img)

# %%
img.shape
# Out:
# (256, 256, 3)

# %%
img
# Out:
# array([[[ 18,  18,  16],
#         [ 15,  15,  13],
#         [ 13,  13,  11],
#         ...,
#         [210, 201, 184],
#         [211, 202, 185],
#         [201, 192, 175]],
#
#        [[  9,   9,   7],
#         [  7,   7,   5],
#         [  5,   5,   3],
#         ...,
#         [216, 207, 190],
#         [224, 215, 198],
#         [202, 193, 176]],
#
#        [[ 15,  15,  13],
#         [ 13,  13,  11],
#         [ 11,  11,   9],
#         ...,
#         [213, 204, 187],
#         [227, 218, 201],
#         [202, 193, 176]],
#
#        ...,
#
#        [[255, 116,  54],
#         [255, 115,  53],
#         [255, 115,  53],
#         ...,
#         [255, 126,  56],
#         [255, 126,  56],
#         [255, 126,  56]],
#
#        [[255, 115,  53],
#         [255, 115,  53],
#         [255, 115,  53],
#         ...,
#         [255, 125,  57],
#         [255, 125,  57],
#         [255, 126,  58]],
#
#        [[254, 114,  52],
#         [254, 114,  52],
#         [254, 114,  52],
# ...

# %% [markdown]
# ### Fake image from test set

# %%
image_path = '/home/thomas/code/dfake/dfake-models/data/real-vs-fake/test/fake/00F8LKY6JC.jpg'
img = np.array(Image.open(image_path))
plt.imshow(img)

# %%
img.shape
# Out:
# (256, 256, 3)

# %%
img
# Out:
# array([[[213, 213, 213],
#         [212, 212, 212],
#         [211, 211, 211],
#         ...,
#         [212, 212, 210],
#         [214, 214, 212],
#         [215, 215, 213]],
#
#        [[211, 211, 211],
#         [211, 211, 211],
#         [210, 210, 210],
#         ...,
#         [211, 211, 209],
#         [213, 213, 211],
#         [213, 213, 211]],
#
#        [[210, 210, 210],
#         [210, 210, 210],
#         [210, 210, 210],
#         ...,
#         [212, 212, 210],
#         [212, 212, 210],
#         [211, 211, 209]],
#
#        ...,
#
#        [[190, 185, 181],
#         [193, 188, 184],
#         [193, 188, 184],
#         ...,
#         [ 99,  78,  57],
#         [ 93,  76,  58],
#         [ 94,  77,  59]],
#
#        [[188, 185, 180],
#         [191, 188, 183],
#         [191, 188, 183],
#         ...,
#         [ 83,  65,  45],
#         [ 85,  68,  52],
#         [ 86,  70,  54]],
#
#        [[187, 184, 179],
#         [190, 187, 182],
#         [190, 187, 182],
# ...

# %% [markdown]
# ### Real image from test set

# %%
image_path = '/home/thomas/code/dfake/dfake-models/data/real-vs-fake/test/real/00001.jpg'
img = np.array(Image.open(image_path))
plt.imshow(img)

# %%
img.shape
# Out:
# (256, 256, 3)

# %%
img
# Out:
# array([[[  2,   2,   0],
#         [  1,   1,   0],
#         [  2,   2,   0],
#         ...,
#         [  8,   3,   0],
#         [  8,   3,   0],
#         [  8,   3,   0]],
#
#        [[  2,   2,   0],
#         [  2,   2,   0],
#         [  2,   2,   0],
#         ...,
#         [  8,   3,   0],
#         [  8,   3,   0],
#         [  8,   3,   0]],
#
#        [[  2,   2,   0],
#         [  2,   2,   0],
#         [  2,   2,   0],
#         ...,
#         [  9,   4,   1],
#         [  9,   4,   1],
#         [  9,   4,   1]],
#
#        ...,
#
#        [[110,  25,   5],
#         [111,  26,   6],
#         [109,  26,   8],
#         ...,
#         [208, 130,  84],
#         [201, 123,  77],
#         [190, 112,  66]],
#
#        [[108,  26,   5],
#         [108,  26,   5],
#         [109,  26,   8],
#         ...,
#         [202, 124,  76],
#         [205, 127,  79],
#         [211, 133,  85]],
#
#        [[109,  27,   6],
#         [108,  26,   5],
#         [107,  24,   6],
# ...
